# %%
#import dependencies
import pandas as pd
import csv 

# File to Load (Remember to Change These)
file = "drought_data/Fires_data.csv"

# Read Purchasing File and store into Pandas data frame
fires_df = pd.read_csv(file)
fires_df
# Out:
#                 X          Y  OBJECTID                FIRE_ID     ASMNT_TYPE  \
# 0     -161.627876  62.013298         1  AK6201316162819840703  Extended (SS)
# 1     -157.536525  63.757053         2  AK6375715753719840609  Extended (SS)
# 2     -155.028811  63.794900         3  AK6379515502919840623  Extended (SS)
# 3     -157.526912  63.929845         4  AK6393015752719840606  Extended (SS)
# 4     -144.673271  64.482310         5  AK6448214467319840607   Initial (SS)
# ...           ...        ...       ...                    ...            ...
# 25609 -107.926112  43.788093     25610  WY4379410794120180726        Initial
# 25610 -107.783680  43.790439     25611  WY4381010781320180813        Initial
# 25611 -107.801509  44.158711     25612  WY4410810779120180708        Initial
# 25612 -107.668955  44.198938     25613  WY4421310768820180614        Initial
# 25613 -108.928560  44.461476     25614  WY4446210893620180812        Initial
#
# ...

# %%
print(list(fires_df.columns))
# Out:
# ['X', 'Y', 'OBJECTID', 'FIRE_ID', 'ASMNT_TYPE', 'PRE_ID', 'POST_ID', 'NODATA_THRESHOLD', 'LOW_THRESHOLD', 'MODERATE_THRESHOLD', 'HIGH_THRESHOLD', 'LATITUDE', 'LONGITUDE', 'FIRE_TYPE', 'FIRE_NAME', 'GREENNESS_THRESHOLD', 'IG_DATE', 'ACRES', 'IRWINID', 'MAP_ID', 'MAP_PROG', 'PERIM_ID', 'DNBR_OFFST', 'DNBR_STDDV', 'COMMENTS']

# %%
wildfire_df = fires_df.loc[fires_df["FIRE_TYPE"] == "Wildfire", :]
wildfire_df
# Out:
#                 X          Y  OBJECTID                FIRE_ID     ASMNT_TYPE  \
# 0     -161.627876  62.013298         1  AK6201316162819840703  Extended (SS)
# 1     -157.536525  63.757053         2  AK6375715753719840609  Extended (SS)
# 2     -155.028811  63.794900         3  AK6379515502919840623  Extended (SS)
# 3     -157.526912  63.929845         4  AK6393015752719840606  Extended (SS)
# 4     -144.673271  64.482310         5  AK6448214467319840607   Initial (SS)
# ...           ...        ...       ...                    ...            ...
# 25609 -107.926112  43.788093     25610  WY4379410794120180726        Initial
# 25610 -107.783680  43.790439     25611  WY4381010781320180813        Initial
# 25611 -107.801509  44.158711     25612  WY4410810779120180708        Initial
# 25612 -107.668955  44.198938     25613  WY4421310768820180614        Initial
# 25613 -108.928560  44.461476     25614  WY4446210893620180812        Initial
#
# ...

# %%
wildfire_df = df.loc[df["Incid_Type,C,254"] == "Wildfire", ["Incid_Type,C,254", "BurnBndLon,C,10", "Asmnt_Type,C,254", "BurnBndLat,C,10"]]
wildfire_df
# Out:
#       Incid_Type,C,254  BurnBndLon,C,10 Asmnt_Type,C,254  BurnBndLat,C,10
# 1             Wildfire         -120.582         Extended           47.972
# 2             Wildfire         -120.746         Extended           47.967
# 3             Wildfire         -120.581         Extended           48.044
# 4             Wildfire         -120.259         Extended           47.895
# 5             Wildfire         -120.215          Initial           47.771
# ...                ...              ...              ...              ...
# 26550         Wildfire          -96.591          Initial           37.858
# 26553         Wildfire         -161.949         Extended           65.142
# 26554         Wildfire         -147.262    Extended (SS)           64.146
# 26555         Wildfire         -112.419         Extended           46.961
# 26556         Wildfire         -155.680         Extended           63.261
#
# [14536 rows x 4 columns]

# %%
wildfire_df
# Out:
#               Event_ID,C,254                         irwinID,C,254  \
# 18652  ID4597111481820140809  053E5451-67FC-4497-A2D8-1C892C6C6146
# 18653  AZ3220611053620140724  33AB36D7-0354-416E-8BDC-DFBF07D7F397
# 19824  AZ3628611317320150624  681165D4-70BF-4E81-A024-50C390056D9E
# 20059  AK6455315210720150621  61943D5B-B1D3-4E08-AEB5-DB01074DCC58
# 22899  CA4128112031520160917  FDE55600-550F-4A2C-ADF6-72B4A2E3F012
# ...                      ...                                   ...
# 26473  AK6202816155120190611  B3DBFAAC-4026-4467-B0D6-8235EAECFB1B
# 26475  AK6814016075420190713  E42A9D0C-4058-4CD9-AB52-30FC136830CD
# 26477  AK6616016124020190620  99A50B70-4778-4D8C-8464-FE64EF712433
# 26478  AK6579516231120190619  09D6F255-3758-41CF-ADC0-8CA3BADB0B77
# 26479  AK6540716251320190619  76C37EE5-9DEE-4CB0-AE5A-3300D20B8A36
#
#         Incid_Name,C,254 Incid_Type,C,254  Map_ID,N,10,0 Map_Prog,C,254  \
# 18652  ELEVATOR MOUNTAIN         Wildfire          22574           MTBS
# ...
